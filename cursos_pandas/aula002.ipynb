# %% [markdown]
# <a href="https://colab.research.google.com/github/rtmazzeo/cursos_python/blob/main/cursos_pandas/aula002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
#  <h2>Lendo e Salvando arquivos CSV</h2>

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data.csv'

# %%
dados_mercado = pd.read_csv(url)
dados_mercado.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dados_primeiras_linhas = pd.read_csv(url, nrows=5) #importar algumas linhas
dados_primeiras_linhas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
dados_selecao = pd.read_csv(url, usecols=['Id','Year_Birth','Income']) #importar colunas
dados_selecao.head(5)
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %%
dados_selecao.to_csv('cliente_mercado.csv',index=False)

# %% [markdown]
# <h3> Para detectar o encoding de um arquivo CSV</h3|>
#
# import chardet
#
# with open('/content/dados.csv', 'rb') as file:
#     print(chardet.detect(file.read()))

# %%
import chardet
with open('/content/cliente_mercado.csv', 'rb') as file:
  print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
#  <h2>Lendo e Salvando arquivos EXCEL</h2>

# %%
url2 = url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2.head(5)
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url).sheet_names # para verificar quantos planilha há no arquivo
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
fontes = pd.read_excel(url,sheet_name='fontes') #ler uma planilha especifica
fontes.head(5)
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
fontes.to_excel('fontes.xlsx',index=False)

# %% [markdown]
# <h3>Importando do Google Planilha</h3>

# %%
# https://docs.google.com/spreadsheets/d/1lzq0k-41-MbbS63C3Q9i1wPvLkSJt9zhr4Jolt1vEog/edit?usp=sharing

# %%
sheet_id ='1lzq0k-41-MbbS63C3Q9i1wPvLkSJt9zhr4Jolt1vEog'

# %%
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_co2_sheets = pd.read_csv(url)
dados_co2_sheets.head(5)
# Out:
#           País ISO 3166-1 alpha-3   Ano Total Carvão Oléo  Gás Cimento Queima  \
# 0  Afeganistão                AFG  1750     0    NaN  NaN  NaN     NaN    NaN
# 1  Afeganistão                AFG  1751     0    NaN  NaN  NaN     NaN    NaN
# 2  Afeganistão                AFG  1752     0    NaN  NaN  NaN     NaN    NaN
# 3  Afeganistão                AFG  1753     0    NaN  NaN  NaN     NaN    NaN
# 4  Afeganistão                AFG  1754     0    NaN  NaN  NaN     NaN    NaN
#
#   Outro Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
#Para especificar uma planilha do google sheets
sheet_id ='1lzq0k-41-MbbS63C3Q9i1wPvLkSJt9zhr4Jolt1vEog'
sheet_name = 'emissoes_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets=pd.read_csv(url_percapita)
percapita_sheets.head(5)
# Out:
#           País ISO 3166-1 alpha-3   Ano Total Carvão Óleo  Gás Cimento Queima  \
# 0  Afeganistão                AFG  1750   NaN    NaN  NaN  NaN     NaN    NaN
# 1  Afeganistão                AFG  1751   NaN    NaN  NaN  NaN     NaN    NaN
# 2  Afeganistão                AFG  1752   NaN    NaN  NaN  NaN     NaN    NaN
# 3  Afeganistão                AFG  1753   NaN    NaN  NaN  NaN     NaN    NaN
# 4  Afeganistão                AFG  1754   NaN    NaN  NaN  NaN     NaN    NaN
#
#    Outro
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
#  <h2>Lendo e manipular arquivos JSON </h2>

# %%
dados = pd.read_json("/content/db.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-ce3bf8dd4dbe> in <cell line: 1>()
# ----> 1 dados = pd.read_json("/content/db.json")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dados #informações aninhadas

# %%
#dados visualizados no https://jsoncrack.com/
df_normalizado =pd.json_normalize(dados['livros'])

# %%
df_normalizado

# %%
df_normalizado.to_json('lista_livros.json')

# %%
import requests
import json

# %%
dados_frutas = requests.get('https://fruityvice.com/api/fruit/all')
resultado = json.loads(dados_frutas.text)
df_frutas = pd.DataFrame(resultado)
df_frutas.head(5)
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %%
dffrutas_normalizado = pd.json_normalize(df_frutas['nutritions'])
dffrutas_normalizado.head(5)
# Out:
#    calories  fat  sugar  carbohydrates  protein
# 0        81  0.0   18.0           18.0      0.0
# 1        29  0.4    5.4            5.5      0.8
# 2        96  0.2   17.2           22.0      1.0
# 3        74  0.2    2.6            3.9      0.9
# 4        57  0.1   10.0           15.0      0.4

# %% [markdown]
# <h3> Lendo dados em HTML de paginas web </h3>

# %%
dados_html = pd.read_html("https://en.wikipedia.org/wiki/AFI%27s_100_Years...100_Movies")

# %%
len(dados_html) # 3 tabelas
# Out:
# 3

# %%
top_filmes = dados_html[1]
top_filmes

# %%
top_filmes.to_html('top_filmes.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-fb6f7af847b1> in <cell line: 1>()
# ----> 1 top_filmes.to_html('top_filmes.html')
#
# NameError: name 'top_filmes' is not defined

# %% [markdown]
# <h3> Lendo arquivos XML</h3>

# %%
url = ('https://raw.githubusercontent.com/alura-cursos/Pandas/main/imdb_top_1000.xml')

# %%
dados_imdb = pd.read_xml(url)
dados_imdb.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
# ...

# %%
dados_imdb.to_xml('filmes_imdb.xml')

# %%
df_wiki = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o')

# %%
len(df_wiki)
# Out:
# 3

# %%
df_wiki[0]
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       339 987 103
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)               806
# 246         NaN     195                           Vaticano               801
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
# 248         NaN       –     Tristão da Cunha (Reino Unido)               241
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                40
#
#      Data      Estimativa Oficial
# ...

# %%
df_wiki[1]
# Out:
#         vdeListas de países                              vdeListas de países.1
# 0     Critérios geográficos  Área Capital Continente Limites Fronteiras ter...
# 1    Critérios demográficos  Esperança de vida Fecundidade Imigrantes Princ...
# 2      Critérios econômicos  Competitividade Carvão Exportação Importação P...
# 3                    Carvão            Exportação Importação Produção Reservas
# 4                   Consumo  Automóveis per capita Celulares Inteligentes B...
# 5              Eletricidade                         Consumo Produção Renovável
# 6               Gás natural    Consumo Exportação Importação Produção Reservas
# 7   Internet de banda larga                               Usuários Assinaturas
# 8                  Petróleo    Consumo Exportação Importação Produção Reservas
# 9        Produção econômica  Alumínio Antimônio Bauxita Bismuto Chumbo Cobr...
# 10    Produto interno bruto      Nominal per capita PPC per capita Crescimento
# ...

# %%
df_wiki[2]
# Out:
#                          0                                                  1
# 0                   Carvão            Exportação Importação Produção Reservas
# 1                  Consumo  Automóveis per capita Celulares Inteligentes B...
# 2             Eletricidade                         Consumo Produção Renovável
# 3              Gás natural    Consumo Exportação Importação Produção Reservas
# 4  Internet de banda larga                               Usuários Assinaturas
# 5                 Petróleo    Consumo Exportação Importação Produção Reservas
# 6       Produção econômica  Alumínio Antimônio Bauxita Bismuto Chumbo Cobr...
# 7    Produto interno bruto      Nominal per capita PPC per capita Crescimento
# 8              Transportes  Aeroportos Heliportos Malha ferroviária Tráfeg...
# 9                 Trabalho  Horas médias trabalhadas Produtividade laboral...

# %% [markdown]
# <h3> Trabalhando com banco de dados </h3>

# %%
import pandas as pd
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.4.49'

# %%
pip install --upgrade 'sqlalchemy<2.0'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# ...

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'
dados = pd.read_csv(url)

# %%
dados.to_sql('clientes',engine,index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %% [markdown]
# <h3> Consultas SQL dentro da tabela criada (clientes)</h3>

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renda="Empregado"'

# %%
empregados = pd.read_sql(query,engine)

# %%
empregados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
empregados.to_sql('empregados',con=engine,index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empregados',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
#especificando colunas
pd.read_sql_table('empregados',engine,columns=['ID_Cliente','Grau_escolaridade','Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
query2 = 'SELECT * FROM empregados WHERE Rendimento_anual>300000'
pesquisa2 = pd.read_sql(query2,engine)
pesquisa2
# Out:
#        ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0         5008804     32   Ensino superior  União-estável                2
# 1         5008805     32   Ensino superior  União-estável                2
# 2         5009031     28      Ensino médio       Solteiro                1
# 3         5009032     28      Ensino médio       Solteiro                1
# 4         6153669     28      Ensino médio       Solteiro                1
# ...           ...    ...               ...            ...              ...
# 19565     6790162     48   Ensino superior       Solteiro                1
# 19566     6806995     44      Ensino médio         Casado                4
# 19567     6836601     26   Ensino superior       Solteiro                1
# 19568     6837905     43      Ensino médio         Casado                3
# 19569     6837906     43      Ensino médio         Casado                3
#
# ...

# %% [markdown]
# <h3> Atualizando banco de dados </h3>

# %%
query3 = 'SELECT * FROM clientes'

# %%
pd.read_sql(query3,engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52      Ensino médio       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = 'UPDATE clientes SET Grau_escolaridade="Ensino Superior" WHERE ID_Cliente=5008808'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52   Ensino Superior       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# <h3>Desafio</h3>
#
# 1)Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
query1 = 'UPDATE clientes SET Rendimento_anual="300000" WHERE ID_Cliente=6840104'
with engine.connect() as conn:
  conn.execute(query1)
pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52   Ensino Superior       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# 2) Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %%
query2 = 'DELETE FROM clientes WHERE ID_Cliente=5008809'
with engine.connect() as conn:
  conn.execute(query2)
pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52   Ensino Superior       Solteiro                1
# 3          5008810     52      Ensino médio       Solteiro                1
# 4          5008811     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438456     6840104     62      Ensino médio     Divorciado                1
# 438457     6840222     43      Ensino médio       Solteiro                1
# 438458     6841878     22   Ensino superior       Solteiro                1
# 438459     6842765     59      Ensino médio         Casado                2
# 438460     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# 3) Criar um novo registro de cliente seguindo as especificações abaixo:
#
# - ID_Cliente: 6850985
# - Idade: 33
# - Grau_escolaridade: Doutorado
# - Estado_civil: Solteiro
# - Tamanho_familia: 1
# - Categoria_de_renda: Empregado
# - Ocupacao: TI
# - Anos_empregado: 2
# - Rendimento_anual: 290000
# - Tem_carro: 0
# - Moradia: Casa/apartamento próprio

# %%
query3 = 'INSERT INTO clientes (ID_Cliente, Idade, Grau_escolaridade, Estado_civil, ' \
        'Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, ' \
        'Rendimento_anual, Tem_carro, Moradia) ' \
        'VALUES (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", ' \
        '2, 290000, 0, "Casa/apartamento próprio")'

with engine.connect() as conn:
    conn.execute(query3)

pd.read_sql_table('clientes',engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52   Ensino Superior       Solteiro                1
# 3          5008810     52      Ensino médio       Solteiro                1
# 4          5008811     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6841878     22   Ensino superior       Solteiro                1
# 438459     6842765     59      Ensino médio         Casado                2
# 438460     6842885     51      Ensino médio         Casado                2
# 438461     5008800     33         Doutorado       Solteiro                1
# 438462     6850985     33         Doutorado       Solteiro                1
#
# ...
